# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Lau Ying Yi Aaron**
# <br>Data Analyst

# %% [markdown]
# *I am interested in data science because I love working with data!*

# %% [markdown]
# ### The following code helps to sum up 2 numbers

# %%
def sum2(x,y):
    return(x+y)
sum2(1,2)
# Out:
# 3

# %% [markdown]
# - Main Bullet Point
#     - sub bullet point
#
# __[youtube Songs](https://www.youtube.com/watch?v=MmTxNCiNtfg)__
#
# <bi>![image.png](attachment:image.png)
